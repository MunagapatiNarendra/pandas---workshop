# %%
pip install panda
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Created wheel for panda: filename=panda-0.3.1-py3-none-any.whl size=7246 sha256=d340a54b93d128b97e79342acba05514ea7806c55e4ec6a140d333e7170b9d8e
#   Stored in directory: c:\users\admin\appdata\local\pip\cache\wheels\98\41\5b\6ca54e0b6a35e1b7248c12f56fcb753dfb7717fefaa0fb45f5
# Successfully built panda
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
pd.__version__
# Out:
# '2.2.2'

# %%
store =  pd.read_csv(r"C:\Users\Admin\OneDrive\Desktop\full stack data science\August month\21st - Pandas\21st - Pandas\Sample - Superstore_Orders.csv")

# %%
store
# Out:
#               Category           City Country/Region      Customer Name  \
# 0      Office Supplies        Houston  United States      Darren Powers
# 1      Office Supplies     Naperville  United States      Phillina Ober
# 2      Office Supplies     Naperville  United States      Phillina Ober
# 3      Office Supplies     Naperville  United States      Phillina Ober
# 4      Office Supplies   Philadelphia  United States         Mick Brown
# ...                ...            ...            ...                ...
# 10189  Office Supplies  New York City  United States  Patrick O'Donnell
# 10190  Office Supplies      Fairfield  United States         Erica Bern
# 10191  Office Supplies       Loveland  United States      Jill Matthias
# 10192       Technology  New York City  United States  Patrick O'Donnell
# 10193  Office Supplies  Charlottetown         Canada        Harry Olson
#
#        Manufacturer  Order Date        Order ID Postal Code  \
# ...

# %%
id(store)
# Out:
# 1965312300896

# %%
len(store)
# Out:
# 10194

# %%
store.columns
# Out:
# Index(['Category', 'City', 'Country/Region', 'Customer Name', 'Manufacturer',
#        'Order Date', 'Order ID', 'Postal Code', 'Product Name', 'Region',
#        'Segment', 'Ship Date', 'Ship Mode', 'State/Province', 'Sub-Category',
#        'Discount', 'Profit', 'Quantity', 'Sales'],
#       dtype='object')

# %%
len(store.columns) # lenth of colmns
# Out:
# 19

# %%
store.shape  # dimensions of the dataset (rows, columns)
# Out:
# (10194, 19)

# %%
store
# Out:
#               Category           City Country/Region      Customer Name  \
# 0      Office Supplies        Houston  United States      Darren Powers
# 1      Office Supplies     Naperville  United States      Phillina Ober
# 2      Office Supplies     Naperville  United States      Phillina Ober
# 3      Office Supplies     Naperville  United States      Phillina Ober
# 4      Office Supplies   Philadelphia  United States         Mick Brown
# ...                ...            ...            ...                ...
# 10189  Office Supplies  New York City  United States  Patrick O'Donnell
# 10190  Office Supplies      Fairfield  United States         Erica Bern
# 10191  Office Supplies       Loveland  United States      Jill Matthias
# 10192       Technology  New York City  United States  Patrick O'Donnell
# 10193  Office Supplies  Charlottetown         Canada        Harry Olson
#
#        Manufacturer  Order Date        Order ID Postal Code  \
# ...

# %%
store.dtypes
# Out:
# Category           object
# City               object
# Country/Region     object
# Customer Name      object
# Manufacturer       object
# Order Date         object
# Order ID           object
# Postal Code        object
# Product Name       object
# Region             object
# Segment            object
# Ship Date          object
# Ship Mode          object
# State/Province     object
# Sub-Category       object
# Discount          float64
# Profit            float64
# Quantity            int64
# Sales             float64
# dtype: object

# %%
# categorical & numreical data
store.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10194 entries, 0 to 10193
# Data columns (total 19 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Category        10194 non-null  object
#  1   City            10194 non-null  object
#  2   Country/Region  10194 non-null  object
#  3   Customer Name   10194 non-null  object
#  4   Manufacturer    10194 non-null  object
#  5   Order Date      10194 non-null  object
#  6   Order ID        10194 non-null  object
#  7   Postal Code     10194 non-null  object
#  8   Product Name    10194 non-null  object
#  9   Region          10194 non-null  object
#  10  Segment         10194 non-null  object
#  11  Ship Date       10194 non-null  object
#  12  Ship Mode       10194 non-null  object
#  13  State/Province  10194 non-null  object
#  14  Sub-Category    10194 non-null  object
#  15  Discount        10194 non-null  float64
#  16  Profit          10194 non-null  float64
# ...

# %%
type(store)
# Out:
# pandas.core.frame.DataFrame

# %%
store.isnull()
# Out:
#        Category   City  Country/Region  Customer Name  Manufacturer  \
# 0         False  False           False          False         False
# 1         False  False           False          False         False
# 2         False  False           False          False         False
# 3         False  False           False          False         False
# 4         False  False           False          False         False
# ...         ...    ...             ...            ...           ...
# 10189     False  False           False          False         False
# 10190     False  False           False          False         False
# 10191     False  False           False          False         False
# 10192     False  False           False          False         False
# 10193     False  False           False          False         False
#
#        Order Date  Order ID  Postal Code  Product Name  Region  Segment  \
# 0           False     False        False         False   False    False
# ...

# %%
store.isnull().sum()
# Out:
# Category          0
# City              0
# Country/Region    0
# Customer Name     0
# Manufacturer      0
# Order Date        0
# Order ID          0
# Postal Code       0
# Product Name      0
# Region            0
# Segment           0
# Ship Date         0
# Ship Mode         0
# State/Province    0
# Sub-Category      0
# Discount          0
# Profit            0
# Quantity          0
# Sales             0
# dtype: int64

# %%
store['Category']
# Out:
# 0        Office Supplies
# 1        Office Supplies
# 2        Office Supplies
# 3        Office Supplies
# 4        Office Supplies
#               ...
# 10189    Office Supplies
# 10190    Office Supplies
# 10191    Office Supplies
# 10192         Technology
# 10193    Office Supplies
# Name: Category, Length: 10194, dtype: object

# %%
store[['Customer Name', 'City']]
# Out:
#            Customer Name           City
# 0          Darren Powers        Houston
# 1          Phillina Ober     Naperville
# 2          Phillina Ober     Naperville
# 3          Phillina Ober     Naperville
# 4             Mick Brown   Philadelphia
# ...                  ...            ...
# 10189  Patrick O'Donnell  New York City
# 10190         Erica Bern      Fairfield
# 10191      Jill Matthias       Loveland
# 10192  Patrick O'Donnell  New York City
# 10193        Harry Olson  Charlottetown
#
# [10194 rows x 2 columns]

# %%
store_categorical = store[['Category', 'City', 'Country/Region', 'Customer Name', 'Manufacturer', 'Order Date', 'Order ID', 'Postal Code', 'Product Name', 'Region', 'Segment', 'Ship Date', 'Ship Mode', 'State/Province', 'Sub-Category']]

# %%
store_categorical
# Out:
#               Category           City Country/Region      Customer Name  \
# 0      Office Supplies        Houston  United States      Darren Powers
# 1      Office Supplies     Naperville  United States      Phillina Ober
# 2      Office Supplies     Naperville  United States      Phillina Ober
# 3      Office Supplies     Naperville  United States      Phillina Ober
# 4      Office Supplies   Philadelphia  United States         Mick Brown
# ...                ...            ...            ...                ...
# 10189  Office Supplies  New York City  United States  Patrick O'Donnell
# 10190  Office Supplies      Fairfield  United States         Erica Bern
# 10191  Office Supplies       Loveland  United States      Jill Matthias
# 10192       Technology  New York City  United States  Patrick O'Donnell
# 10193  Office Supplies  Charlottetown         Canada        Harry Olson
#
#        Manufacturer  Order Date        Order ID Postal Code  \
# ...

# %%
store_categorical.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10194 entries, 0 to 10193
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Category        10194 non-null  object
#  1   City            10194 non-null  object
#  2   Country/Region  10194 non-null  object
#  3   Customer Name   10194 non-null  object
#  4   Manufacturer    10194 non-null  object
#  5   Order Date      10194 non-null  object
#  6   Order ID        10194 non-null  object
#  7   Postal Code     10194 non-null  object
#  8   Product Name    10194 non-null  object
#  9   Region          10194 non-null  object
#  10  Segment         10194 non-null  object
#  11  Ship Date       10194 non-null  object
#  12  Ship Mode       10194 non-null  object
#  13  State/Province  10194 non-null  object
#  14  Sub-Category    10194 non-null  object
# dtypes: object(15)
# memory usage: 1.2+ MB

# %%
store_numerical = store[['Discount', 'Profit', 'Quantity', 'Sales']]
store_numerical
# Out:
#        Discount   Profit  Quantity    Sales
# 0           0.2   5.5512         2   16.448
# 1           0.8  -5.4870         2    3.540
# 2           0.2   4.2717         3   11.784
# 3           0.2 -64.7748         3  272.736
# 4           0.2   4.8840         3   19.536
# ...         ...      ...       ...      ...
# 10189       0.2  19.7910         3   52.776
# 10190       0.2   6.4750         2   20.720
# 10191       0.2  -0.6048         3    3.024
# 10192       0.0   2.7279         7   90.930
# 10193       0.2  -0.6048         3    3.024
#
# [10194 rows x 4 columns]

# %%
store
# Out:
#               Category           City Country/Region      Customer Name  \
# 0      Office Supplies        Houston  United States      Darren Powers
# 1      Office Supplies     Naperville  United States      Phillina Ober
# 2      Office Supplies     Naperville  United States      Phillina Ober
# 3      Office Supplies     Naperville  United States      Phillina Ober
# 4      Office Supplies   Philadelphia  United States         Mick Brown
# ...                ...            ...            ...                ...
# 10189  Office Supplies  New York City  United States  Patrick O'Donnell
# 10190  Office Supplies      Fairfield  United States         Erica Bern
# 10191  Office Supplies       Loveland  United States      Jill Matthias
# 10192       Technology  New York City  United States  Patrick O'Donnell
# 10193  Office Supplies  Charlottetown         Canada        Harry Olson
#
#        Manufacturer  Order Date        Order ID Postal Code  \
# ...

# %%
store.head() # top 5 rows
# Out:
#           Category          City Country/Region  Customer Name  Manufacturer  \
# 0  Office Supplies       Houston  United States  Darren Powers  Message Book
# 1  Office Supplies    Naperville  United States  Phillina Ober           GBC
# 2  Office Supplies    Naperville  United States  Phillina Ober         Avery
# 3  Office Supplies    Naperville  United States  Phillina Ober         SAFCO
# 4  Office Supplies  Philadelphia  United States     Mick Brown         Avery
#
#    Order Date        Order ID Postal Code  \
# 0  03-01-2020  US-2020-103800       77015
# 1  04-01-2020  US-2020-112326       60540
# 2  04-01-2020  US-2020-112326       60540
# 3  04-01-2020  US-2020-112326       60540
# 4  05-01-2020  US-2020-141817       19143
#
#                                         Product Name   Region      Segment  \
# 0  Message Book, Wirebound, Four 5 1/2" X 4" Form...  Central     Consumer
# 1         GBC Standard Plastic Binding Systems Combs  Central  Home Office
# ...

# %%
store.tail() # bottom 5 records
# Out:
#               Category           City Country/Region      Customer Name  \
# 10189  Office Supplies  New York City  United States  Patrick O'Donnell
# 10190  Office Supplies      Fairfield  United States         Erica Bern
# 10191  Office Supplies       Loveland  United States      Jill Matthias
# 10192       Technology  New York City  United States  Patrick O'Donnell
# 10193  Office Supplies  Charlottetown         Canada        Harry Olson
#
#        Manufacturer  Order Date        Order ID Postal Code  \
# 10189  Wilson Jones  30-12-2023  US-2023-143259       10009
# 10190           GBC  30-12-2023  US-2023-115427       94533
# 10191         Other  30-12-2023  US-2023-156720       80538
# 10192         Other  30-12-2023  US-2023-143259       10009
# 10193  Wilson Jones  30-12-2023  CA-2023-143500         C0A
#
#                                Product Name Region    Segment   Ship Date  \
# 10189  Wilson Jones Legal Size Ring Binders   East   Consumer  03-01-2024
# ...

# %% [markdown]
# # indexing slicing

# %%
store[:]
# Out:
#               Category           City Country/Region      Customer Name  \
# 0      Office Supplies        Houston  United States      Darren Powers
# 1      Office Supplies     Naperville  United States      Phillina Ober
# 2      Office Supplies     Naperville  United States      Phillina Ober
# 3      Office Supplies     Naperville  United States      Phillina Ober
# 4      Office Supplies   Philadelphia  United States         Mick Brown
# ...                ...            ...            ...                ...
# 10189  Office Supplies  New York City  United States  Patrick O'Donnell
# 10190  Office Supplies      Fairfield  United States         Erica Bern
# 10191  Office Supplies       Loveland  United States      Jill Matthias
# 10192       Technology  New York City  United States  Patrick O'Donnell
# 10193  Office Supplies  Charlottetown         Canada        Harry Olson
#
#        Manufacturer  Order Date        Order ID Postal Code  \
# ...

# %%
store[0:10]
# Out:
#           Category          City Country/Region  Customer Name  Manufacturer  \
# 0  Office Supplies       Houston  United States  Darren Powers  Message Book
# 1  Office Supplies    Naperville  United States  Phillina Ober           GBC
# 2  Office Supplies    Naperville  United States  Phillina Ober         Avery
# 3  Office Supplies    Naperville  United States  Phillina Ober         SAFCO
# 4  Office Supplies  Philadelphia  United States     Mick Brown         Avery
# 5        Furniture     Henderson  United States  Maria Etezadi        Global
# 6  Office Supplies     Henderson  United States  Maria Etezadi        Rogers
# 7  Office Supplies        Athens  United States  Jack O'Briant         Dixon
# 8  Office Supplies     Henderson  United States  Maria Etezadi         Ibico
# 9  Office Supplies     Henderson  United States  Maria Etezadi      Alliance
#
#    Order Date        Order ID Postal Code  \
# 0  03-01-2020  US-2020-103800       77015
# ...

# %%
store[0:10:2] # start:stop:step
# Out:
#           Category          City Country/Region  Customer Name  Manufacturer  \
# 0  Office Supplies       Houston  United States  Darren Powers  Message Book
# 2  Office Supplies    Naperville  United States  Phillina Ober         Avery
# 4  Office Supplies  Philadelphia  United States     Mick Brown         Avery
# 6  Office Supplies     Henderson  United States  Maria Etezadi        Rogers
# 8  Office Supplies     Henderson  United States  Maria Etezadi         Ibico
#
#    Order Date        Order ID Postal Code  \
# 0  03-01-2020  US-2020-103800       77015
# 2  04-01-2020  US-2020-112326       60540
# 4  05-01-2020  US-2020-141817       19143
# 6  06-01-2020  US-2020-167199       42420
# 8  06-01-2020  US-2020-167199       42420
#
#                                         Product Name   Region      Segment  \
# 0  Message Book, Wirebound, Four 5 1/2" X 4" Form...  Central     Consumer
# 2                                          Avery 508  Central  Home Office
# ...

# %%
store[::-1]
# Out:
#               Category           City Country/Region      Customer Name  \
# 10193  Office Supplies  Charlottetown         Canada        Harry Olson
# 10192       Technology  New York City  United States  Patrick O'Donnell
# 10191  Office Supplies       Loveland  United States      Jill Matthias
# 10190  Office Supplies      Fairfield  United States         Erica Bern
# 10189  Office Supplies  New York City  United States  Patrick O'Donnell
# ...                ...            ...            ...                ...
# 4      Office Supplies   Philadelphia  United States         Mick Brown
# 3      Office Supplies     Naperville  United States      Phillina Ober
# 2      Office Supplies     Naperville  United States      Phillina Ober
# 1      Office Supplies     Naperville  United States      Phillina Ober
# 0      Office Supplies        Houston  United States      Darren Powers
#
#        Manufacturer  Order Date        Order ID Postal Code  \
# ...

# %%
store[6:7]
# Out:
#           Category       City Country/Region  Customer Name Manufacturer  \
# 6  Office Supplies  Henderson  United States  Maria Etezadi       Rogers
#
#    Order Date        Order ID Postal Code  \
# 6  06-01-2020  US-2020-167199       42420
#
#                               Product Name Region      Segment   Ship Date  \
# 6  Rogers Handheld Barrel Pencil Sharpener  South  Home Office  10-01-2020
#
#         Ship Mode State/Province Sub-Category  Discount  Profit  Quantity  \
# 6  Standard Class       Kentucky          Art       0.0  1.4796         2
#
#    Sales
# 6   5.48

# %%
store.describe()  # numeric values
# Out:
#            Discount        Profit      Quantity         Sales
# count  10194.000000  10194.000000  10194.000000  10194.000000
# mean       0.155385     28.673417      3.791838    228.225854
# std        0.206249    232.465115      2.228317    619.906839
# min        0.000000  -6599.978000      1.000000      0.444000
# 25%        0.000000      1.760800      2.000000     17.220000
# 50%        0.200000      8.690000      3.000000     53.910000
# 75%        0.200000     29.297925      5.000000    209.500000
# max        0.800000   8399.976000     14.000000  22638.480000

# %%
store[['Customer Name', 'City']][0:10:2]
# Out:
#    Customer Name          City
# 0  Darren Powers       Houston
# 2  Phillina Ober    Naperville
# 4     Mick Brown  Philadelphia
# 6  Maria Etezadi     Henderson
# 8  Maria Etezadi     Henderson

# %%
store.head()
# Out:
#           Category          City Country/Region  Customer Name  Manufacturer  \
# 0  Office Supplies       Houston  United States  Darren Powers  Message Book
# 1  Office Supplies    Naperville  United States  Phillina Ober           GBC
# 2  Office Supplies    Naperville  United States  Phillina Ober         Avery
# 3  Office Supplies    Naperville  United States  Phillina Ober         SAFCO
# 4  Office Supplies  Philadelphia  United States     Mick Brown         Avery
#
#    Order Date        Order ID Postal Code  \
# 0  03-01-2020  US-2020-103800       77015
# 1  04-01-2020  US-2020-112326       60540
# 2  04-01-2020  US-2020-112326       60540
# 3  04-01-2020  US-2020-112326       60540
# 4  05-01-2020  US-2020-141817       19143
#
#                                         Product Name   Region      Segment  \
# 0  Message Book, Wirebound, Four 5 1/2" X 4" Form...  Central     Consumer
# 1         GBC Standard Plastic Binding Systems Combs  Central  Home Office
# ...

# %%
store.loc[1]  # print the first row only
# Out:
# Category                                     Office Supplies
# City                                              Naperville
# Country/Region                                 United States
# Customer Name                                  Phillina Ober
# Manufacturer                                             GBC
# Order Date                                        04-01-2020
# Order ID                                      US-2020-112326
# Postal Code                                            60540
# Product Name      GBC Standard Plastic Binding Systems Combs
# Region                                               Central
# Segment                                          Home Office
# Ship Date                                         08-01-2020
# Ship Mode                                     Standard Class
# State/Province                                      Illinois
# Sub-Category                                         Binders
# ...

# %%
store.loc[1,['City']]
# Out:
# City    Naperville
# Name: 1, dtype: object

# %%
store.loc[0:5] # stop index included
# Out:
#           Category          City Country/Region  Customer Name  Manufacturer  \
# 0  Office Supplies       Houston  United States  Darren Powers  Message Book
# 1  Office Supplies    Naperville  United States  Phillina Ober           GBC
# 2  Office Supplies    Naperville  United States  Phillina Ober         Avery
# 3  Office Supplies    Naperville  United States  Phillina Ober         SAFCO
# 4  Office Supplies  Philadelphia  United States     Mick Brown         Avery
# 5        Furniture     Henderson  United States  Maria Etezadi        Global
#
#    Order Date        Order ID Postal Code  \
# 0  03-01-2020  US-2020-103800       77015
# 1  04-01-2020  US-2020-112326       60540
# 2  04-01-2020  US-2020-112326       60540
# 3  04-01-2020  US-2020-112326       60540
# 4  05-01-2020  US-2020-141817       19143
# 5  06-01-2020  US-2020-167199       42420
#
#                                         Product Name   Region      Segment  \
# ...

# %%
store.loc[1:3, ['Customer Name', 'City', 'Discount']]
# Out:
#    Customer Name        City  Discount
# 1  Phillina Ober  Naperville       0.8
# 2  Phillina Ober  Naperville       0.2
# 3  Phillina Ober  Naperville       0.2

# %%
store.loc[1:2, 'City']
# Out:
# 1    Naperville
# 2    Naperville
# Name: City, dtype: object

# %%
store.loc[1:3, "City":"Discount"]
# Out:
#          City Country/Region  Customer Name Manufacturer  Order Date  \
# 1  Naperville  United States  Phillina Ober          GBC  04-01-2020
# 2  Naperville  United States  Phillina Ober        Avery  04-01-2020
# 3  Naperville  United States  Phillina Ober        SAFCO  04-01-2020
#
#          Order ID Postal Code                                Product Name  \
# 1  US-2020-112326       60540  GBC Standard Plastic Binding Systems Combs
# 2  US-2020-112326       60540                                   Avery 508
# 3  US-2020-112326       60540               SAFCO Boltless Steel Shelving
#
#     Region      Segment   Ship Date       Ship Mode State/Province  \
# 1  Central  Home Office  08-01-2020  Standard Class       Illinois
# 2  Central  Home Office  08-01-2020  Standard Class       Illinois
# 3  Central  Home Office  08-01-2020  Standard Class       Illinois
#
#   Sub-Category  Discount
# 1      Binders       0.8
# 2       Labels       0.2
# 3      Storage       0.2

# %%
store.iloc[1:3]  # stop index excluded
# Out:
#           Category        City Country/Region  Customer Name Manufacturer  \
# 1  Office Supplies  Naperville  United States  Phillina Ober          GBC
# 2  Office Supplies  Naperville  United States  Phillina Ober        Avery
#
#    Order Date        Order ID Postal Code  \
# 1  04-01-2020  US-2020-112326       60540
# 2  04-01-2020  US-2020-112326       60540
#
#                                  Product Name   Region      Segment  \
# 1  GBC Standard Plastic Binding Systems Combs  Central  Home Office
# 2                                   Avery 508  Central  Home Office
#
#     Ship Date       Ship Mode State/Province Sub-Category  Discount  Profit  \
# 1  08-01-2020  Standard Class       Illinois      Binders       0.8 -5.4870
# 2  08-01-2020  Standard Class       Illinois       Labels       0.2  4.2717
#
#    Quantity   Sales
# 1         2   3.540
# 2         3  11.784

# %% [markdown]
# # Sorting Store

# %%
store.sort_values('Discount').head(100)    # ASCEDING VALUES
# Out:
#              Category           City Country/Region      Customer Name  \
# 8634  Office Supplies    Springfield  United States     Robert Waldorf
# 8187  Office Supplies      San Diego  United States        Shaun Weien
# 6883  Office Supplies        Jackson  United States        Andy Reiter
# 8189  Office Supplies          Salem  United States     Anne McFarland
# 6882  Office Supplies        Jackson  United States        Andy Reiter
# ...               ...            ...            ...                ...
# 3542       Technology  New York City  United States  Valerie Dominguez
# 8137  Office Supplies  New York City  United States     Michelle Moray
# 3541       Technology  New York City  United States       Quincy Jones
# 8126       Technology    Westminster  United States      Toby Carlisle
# 6895  Office Supplies      Waterbury  United States       Jeremy Farry
#
#      Manufacturer  Order Date        Order ID Postal Code  \
# ...

# %%
store.sort_values('Discount', ascending=False).head(100)   # DESCENDING VALUES
# Out:
#              Category     City Country/Region      Customer Name Manufacturer  \
# 7005  Office Supplies  Houston  United States       Tom Prescott       Belkin
# 5763  Office Supplies   Aurora  United States  Eugene Hildebrand        Avery
# 5879  Office Supplies   Quincy  United States       Sarah Jordon   Pressboard
# 2525  Office Supplies   Aurora  United States      Dennis Pardue   Tripp Lite
# 5851  Office Supplies  Houston  United States    Matt Hagelstein          GBC
# ...               ...      ...            ...                ...          ...
# 5087  Office Supplies  Houston  United States      Dave Hallsten       Holmes
# 5492  Office Supplies   Dallas  United States       Tom Prescott      Angle-D
# 539   Office Supplies  Chicago  United States    Laurel Elliston     Fellowes
# 2771  Office Supplies  Houston  United States    Richard Bierner       Belkin
# 5439  Office Supplies  Houston  United States  Dorothy Dickinson          GBC
#
# ...

# %% [markdown]
# # Adding Columns

# %%
store.describe()
# Out:
#            Discount        Profit      Quantity         Sales
# count  10194.000000  10194.000000  10194.000000  10194.000000
# mean       0.155385     28.673417      3.791838    228.225854
# std        0.206249    232.465115      2.228317    619.906839
# min        0.000000  -6599.978000      1.000000      0.444000
# 25%        0.000000      1.760800      2.000000     17.220000
# 50%        0.200000      8.690000      3.000000     53.910000
# 75%        0.200000     29.297925      5.000000    209.500000
# max        0.800000   8399.976000     14.000000  22638.480000

# %%
store.head()
# Out:
#           Category          City Country/Region  Customer Name  Manufacturer  \
# 0  Office Supplies       Houston  United States  Darren Powers  Message Book
# 1  Office Supplies    Naperville  United States  Phillina Ober           GBC
# 2  Office Supplies    Naperville  United States  Phillina Ober         Avery
# 3  Office Supplies    Naperville  United States  Phillina Ober         SAFCO
# 4  Office Supplies  Philadelphia  United States     Mick Brown         Avery
#
#    Order Date        Order ID Postal Code  \
# 0  03-01-2020  US-2020-103800       77015
# 1  04-01-2020  US-2020-112326       60540
# 2  04-01-2020  US-2020-112326       60540
# 3  04-01-2020  US-2020-112326       60540
# 4  05-01-2020  US-2020-141817       19143
#
#                                         Product Name   Region      Segment  \
# 0  Message Book, Wirebound, Four 5 1/2" X 4" Form...  Central     Consumer
# 1         GBC Standard Plastic Binding Systems Combs  Central  Home Office
# ...

# %%
store['new_columns'] = 0

# %%
store.columns
# Out:
# Index(['Category', 'City', 'Country/Region', 'Customer Name', 'Manufacturer',
#        'Order Date', 'Order ID', 'Postal Code', 'Product Name', 'Region',
#        'Segment', 'Ship Date', 'Ship Mode', 'State/Province', 'Sub-Category',
#        'Discount', 'Profit', 'Quantity', 'Sales', 'new_columns'],
#       dtype='object')

# %%
store['new_columns']
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 10189    0
# 10190    0
# 10191    0
# 10192    0
# 10193    0
# Name: new_columns, Length: 10194, dtype: int64

# %%
store.head()
# Out:
#           Category          City Country/Region  Customer Name  Manufacturer  \
# 0  Office Supplies       Houston  United States  Darren Powers  Message Book
# 1  Office Supplies    Naperville  United States  Phillina Ober           GBC
# 2  Office Supplies    Naperville  United States  Phillina Ober         Avery
# 3  Office Supplies    Naperville  United States  Phillina Ober         SAFCO
# 4  Office Supplies  Philadelphia  United States     Mick Brown         Avery
#
#    Order Date        Order ID Postal Code  \
# 0  03-01-2020  US-2020-103800       77015
# 1  04-01-2020  US-2020-112326       60540
# 2  04-01-2020  US-2020-112326       60540
# 3  04-01-2020  US-2020-112326       60540
# 4  05-01-2020  US-2020-141817       19143
#
#                                         Product Name   Region      Segment  \
# 0  Message Book, Wirebound, Four 5 1/2" X 4" Form...  Central     Consumer
# 1         GBC Standard Plastic Binding Systems Combs  Central  Home Office
# ...

# %% [markdown]
# # Removing columns

# %%
store.drop(columns='new_columns')  # only temparary delete the columnss
# Out:
#               Category           City Country/Region      Customer Name  \
# 0      Office Supplies        Houston  United States      Darren Powers
# 1      Office Supplies     Naperville  United States      Phillina Ober
# 2      Office Supplies     Naperville  United States      Phillina Ober
# 3      Office Supplies     Naperville  United States      Phillina Ober
# 4      Office Supplies   Philadelphia  United States         Mick Brown
# ...                ...            ...            ...                ...
# 10189  Office Supplies  New York City  United States  Patrick O'Donnell
# 10190  Office Supplies      Fairfield  United States         Erica Bern
# 10191  Office Supplies       Loveland  United States      Jill Matthias
# 10192       Technology  New York City  United States  Patrick O'Donnell
# 10193  Office Supplies  Charlottetown         Canada        Harry Olson
#
#        Manufacturer  Order Date        Order ID Postal Code  \
# ...

# %%
store.head(1)
# Out:
#           Category     City Country/Region  Customer Name  Manufacturer  \
# 0  Office Supplies  Houston  United States  Darren Powers  Message Book
#
#    Order Date        Order ID Postal Code  \
# 0  03-01-2020  US-2020-103800       77015
#
#                                         Product Name   Region   Segment  \
# 0  Message Book, Wirebound, Four 5 1/2" X 4" Form...  Central  Consumer
#
#     Ship Date       Ship Mode State/Province Sub-Category  Discount  Profit  \
# 0  07-01-2020  Standard Class          Texas        Paper       0.2  5.5512
#
#    Quantity   Sales  new_columns
# 0         2  16.448            0

# %%
store.drop(columns = 'new_columns', inplace = True)

# %%
store.head(1)
# Out:
#           Category     City Country/Region  Customer Name  Manufacturer  \
# 0  Office Supplies  Houston  United States  Darren Powers  Message Book
#
#    Order Date        Order ID Postal Code  \
# 0  03-01-2020  US-2020-103800       77015
#
#                                         Product Name   Region   Segment  \
# 0  Message Book, Wirebound, Four 5 1/2" X 4" Form...  Central  Consumer
#
#     Ship Date       Ship Mode State/Province Sub-Category  Discount  Profit  \
# 0  07-01-2020  Standard Class          Texas        Paper       0.2  5.5512
#
#    Quantity   Sales
# 0         2  16.448

# %%
store
# Out:
#               Category           City Country/Region      Customer Name  \
# 0      Office Supplies        Houston  United States      Darren Powers
# 1      Office Supplies     Naperville  United States      Phillina Ober
# 2      Office Supplies     Naperville  United States      Phillina Ober
# 3      Office Supplies     Naperville  United States      Phillina Ober
# 4      Office Supplies   Philadelphia  United States         Mick Brown
# ...                ...            ...            ...                ...
# 10189  Office Supplies  New York City  United States  Patrick O'Donnell
# 10190  Office Supplies      Fairfield  United States         Erica Bern
# 10191  Office Supplies       Loveland  United States      Jill Matthias
# 10192       Technology  New York City  United States  Patrick O'Donnell
# 10193  Office Supplies  Charlottetown         Canada        Harry Olson
#
#        Manufacturer  Order Date        Order ID Postal Code  \
# ...

# %% [markdown]
# # Removing Duplicates

# %%
store.duplicated()     # result in boolean values
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 10189    False
# 10190    False
# 10191    False
# 10192    False
# 10193    False
# Length: 10194, dtype: bool

# %%
# we don't have any duplicated values
# we have duplicates use this key word 
# its removing duplicates values
# Data_frame.drop_duplicates(inplace=True)

# %% [markdown]
# # find out the missing data

# %%
store.dropna()
# Out:
#               Category           City Country/Region      Customer Name  \
# 0      Office Supplies        Houston  United States      Darren Powers
# 1      Office Supplies     Naperville  United States      Phillina Ober
# 2      Office Supplies     Naperville  United States      Phillina Ober
# 3      Office Supplies     Naperville  United States      Phillina Ober
# 4      Office Supplies   Philadelphia  United States         Mick Brown
# ...                ...            ...            ...                ...
# 10189  Office Supplies  New York City  United States  Patrick O'Donnell
# 10190  Office Supplies      Fairfield  United States         Erica Bern
# 10191  Office Supplies       Loveland  United States      Jill Matthias
# 10192       Technology  New York City  United States  Patrick O'Donnell
# 10193  Office Supplies  Charlottetown         Canada        Harry Olson
#
#        Manufacturer  Order Date        Order ID Postal Code  \
# ...

# %%
store.dropna().sum()
# Out:
# Category          Office SuppliesOffice SuppliesOffice SuppliesO...
# City              HoustonNapervilleNapervilleNapervillePhiladelp...
# Country/Region    United StatesUnited StatesUnited StatesUnited ...
# Customer Name     Darren PowersPhillina OberPhillina OberPhillin...
# Manufacturer      Message BookGBCAverySAFCOAveryGlobalRogersDixo...
# Order Date        03-01-202004-01-202004-01-202004-01-202005-01-...
# Order ID          US-2020-103800US-2020-112326US-2020-112326US-2...
# Postal Code       7701560540605406054019143424204242030605424204...
# Product Name      Message Book, Wirebound, Four 5 1/2" X 4" Form...
# Region            CentralCentralCentralCentralEastSouthSouthSout...
# Segment           ConsumerHome OfficeHome OfficeHome OfficeConsu...
# Ship Date         07-01-202008-01-202008-01-202008-01-202012-01-...
# Ship Mode         Standard ClassStandard ClassStandard ClassStan...
# State/Province    TexasIllinoisIllinoisIllinoisPennsylvaniaKentu...
# ...

# %%
store
# Out:
#               Category           City Country/Region      Customer Name  \
# 0      Office Supplies        Houston  United States      Darren Powers
# 1      Office Supplies     Naperville  United States      Phillina Ober
# 2      Office Supplies     Naperville  United States      Phillina Ober
# 3      Office Supplies     Naperville  United States      Phillina Ober
# 4      Office Supplies   Philadelphia  United States         Mick Brown
# ...                ...            ...            ...                ...
# 10189  Office Supplies  New York City  United States  Patrick O'Donnell
# 10190  Office Supplies      Fairfield  United States         Erica Bern
# 10191  Office Supplies       Loveland  United States      Jill Matthias
# 10192       Technology  New York City  United States  Patrick O'Donnell
# 10193  Office Supplies  Charlottetown         Canada        Harry Olson
#
#        Manufacturer  Order Date        Order ID Postal Code  \
# ...

# %%
store.isnull().sum()
# Out:
# Category          0
# City              0
# Country/Region    0
# Customer Name     0
# Manufacturer      0
# Order Date        0
# Order ID          0
# Postal Code       0
# Product Name      0
# Region            0
# Segment           0
# Ship Date         0
# Ship Mode         0
# State/Province    0
# Sub-Category      0
# Discount          0
# Profit            0
# Quantity          0
# Sales             0
# dtype: int64

# %% [markdown]
# # In this proct what you learn
# # 1.Create a data frame
# # 2.Indexing and Slicing
# # 3.Sorting Data frame
# # 4.Adding columns
# # 5.Removing Columns
# # 6.Knowing duplicates
# # 7.Removing duplicates
# # 8.Find out the missing values
# # 9.Fill the missing value
